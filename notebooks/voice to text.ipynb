# %%
import speech_recognition as sr

# %%
r = sr.Recognizer()

# %%
harvard = sr.AudioFile('enree.wav')
with harvard as source:
    r.adjust_for_ambient_noise(source)
    audio = r.record(source)

# %%
r.recognize_google(audio)
# Out:
# 'today I want you to ask yourself this one question why not you why not you to do something for work that you love'
